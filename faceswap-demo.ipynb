# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/srcimgs/876.jpg
# /kaggle/input/targetvidz/target.mp4

# %%
# !nvidia-smi
# Out:
# Fri Jul 24 11:41:46 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    28W / 250W |      0MiB / 16280MiB |      6%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !git clone https://github.com/AliaksandrSiarohin/motion-cosegmentation.git
# Out:
# Cloning into 'motion-cosegmentation'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 83 (delta 25), reused 53 (delta 7), pack-reused 0
# Unpacking objects: 100% (83/83), done.

# %%
# %cd motion-cosegmentation/
# !git clone https://github.com/AliaksandrSiarohin/face-makeup.PyTorch face_parsing
# Out:
# /kaggle/working/motion-cosegmentation

# %%
# !conda install -y gdown
# !pip install imageio_ffmpeg
# !mkdir weights/
# download first order weights
import gdown
id='1n2CqYEjM82X7sE40xrZpmnOxF6NekYW0'
url = 'https://drive.google.com/uc?id='
outdir='weights/'
gdown.download(url+id, outdir, quiet=False)
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gdown-3.12.0               |     pyh9f0ad1d_0          12 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          12 KB
#
# The following NEW packages will be INSTALLED:
#
#   gdown              conda-forge/noarch::gdown-3.12.0-pyh9f0ad1d_0
#
#
#
# ...
# gdown-3.12.0         | 12 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# mkdir: cannot create directory ‘weights/’: File exists
# Downloading...
# From: https://drive.google.com/uc?id=1n2CqYEjM82X7sE40xrZpmnOxF6NekYW0
# ...

# %%
# !python part_swap.py --source_image /kaggle/input/srcimgs/unnamed.jpg --target_video /kaggle/input/targetvidz/target.mp4 --checkpoint weights/vox-first-order.pth.tar --config config/vox-256-sem-10segments.yaml --supervised --first_order_motion_model
# Out:
# part_swap.py:105: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)
# Segmentation part initialized at random.
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100%|███████████████████████████████████████| 44.7M/44.7M [00:00<00:00, 185MB/s]
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# ...
